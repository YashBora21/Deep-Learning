# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image


from tensorflow.keras.models import load_model

model = load_model("pneumonia_model.keras", compile=False)

# 🔹 Load image
img_path = r"C:\Users\Lenovo\OneDrive\Pictures\Screenshots\Screenshot 2026-03-20 100822.png"   # your image path

img = image.load_img(img_path, target_size=(224, 224))
img_array = image.img_to_array(img)

# 🔹 Normalize
img_array = img_array / 255.0

# 🔹 Add batch dimension
img_array = np.expand_dims(img_array, axis=0)

# 🔹 Predict
prediction = model.predict(img_array)

# 🔹 Print raw output
print("Raw prediction:", prediction)

# 🔹 Convert to label
if prediction[0][0] > 0.5:
    label = "PNEUMONIA 🫁"
else:
    label = "NORMAL ✅"

print("Prediction:", label)

# 🔹 Show image
plt.imshow(img)
plt.title(label)
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 from tensorflow.keras.preprocessing import image
#       5 import os
#       6 os.environ["TF_USE_LEGACY_KERAS"] = "1"
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.21.0-cp310-cp310-win_amd64.whl (350.6 MB)
# Collecting requests<3,>=2.21.0
#   Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Collecting wrapt>=1.11.0
#   Downloading wrapt-2.1.2-cp310-cp310-win_amd64.whl (60 kB)
# Collecting ml_dtypes<1.0.0,>=0.5.1
#   Downloading ml_dtypes-0.5.4-cp310-cp310-win_amd64.whl (210 kB)
# Collecting absl-py>=1.0.0
#   Downloading absl_py-2.4.0-py3-none-any.whl (135 kB)
# Collecting h5py<3.15.0,>=3.11.0
#   Downloading h5py-3.14.0-cp310-cp310-win_amd64.whl (2.9 MB)
# Collecting libclang>=13.0.0
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.78.0-cp310-cp310-win_amd64.whl (4.8 MB)
# Collecting flatbuffers>=25.9.23
#   Downloading flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Collecting keras>=3.12.0
#   Downloading keras-3.12.1-py3-none-any.whl (1.5 MB)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from tensorflow) (4.14.0)
# Collecting google_pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting opt_einsum>=2.3.2
#   Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.2.6)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: setuptools in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (57.4.0)
# Requirement already satisfied: packaging in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from tensorflow) (1.17.0)
# Collecting protobuf<8.0.0,>=6.31.1
#   Downloading protobuf-7.34.0-cp310-abi3-win_amd64.whl (437 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1
#   Downloading gast-0.7.0-py3-none-any.whl (22 kB)
# Collecting wheel<1.0,>=0.23.0
#   Downloading wheel-0.46.3-py3-none-any.whl (30 kB)
# Collecting optree
#   Downloading optree-0.19.0-cp310-cp310-win_amd64.whl (321 kB)
# Collecting namex
#   Using cached namex-0.1.0-py3-none-any.whl (5.9 kB)
# Collecting rich
#   Downloading rich-14.3.3-py3-none-any.whl (310 kB)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2026.2.25-py3-none-any.whl (153 kB)
# Collecting charset_normalizer<4,>=2
#   Downloading charset_normalizer-3.4.6-cp310-cp310-win_amd64.whl (154 kB)
# Collecting idna<4,>=2.5
#   Downloading idna-3.11-py3-none-any.whl (71 kB)
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from rich->keras>=3.12.0->tensorflow) (2.19.1)
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: mdurl, markdown-it-py, wheel, urllib3, rich, optree, namex, ml-dtypes, idna, h5py, charset-normalizer, certifi, absl-py, wrapt, termcolor, requests, protobuf, opt-einsum, libclang, keras, grpcio, google-pasta, gast, flatbuffers, astunparse, tensorflow
# Successfully installed absl-py-2.4.0 astunparse-1.6.3 certifi-2026.2.25 charset-normalizer-3.4.6 flatbuffers-25.12.19 gast-0.7.0 google-pasta-0.2.0 grpcio-1.78.0 h5py-3.14.0 idna-3.11 keras-3.12.1 libclang-18.1.1 markdown-it-py-4.0.0 mdurl-0.1.2 ml-dtypes-0.5.4 namex-0.1.0 opt-einsum-3.4.0 optree-0.19.0 protobuf-7.34.0 requests-2.32.5 rich-14.3.3 tensorflow-2.21.0 termcolor-3.3.0 urllib3-2.6.3 wheel-0.46.3 wrapt-2.1.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 26.0.1 is available.
# You should consider upgrading via the 'c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
